# %%
pip install pycoingecko
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

from datetime import datetime
import pandas as pd
import numpy as np

# %%
cg.ping()
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %%
cg.get_price(ids="bitcoin", vs_currencies='usd')
# Out:
# {'bitcoin': {'usd': 49598}}

# %%
cg.get_coin_history_by_id('bitcoin','30-12-2017')
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'localization': {'en': 'Bitcoin',
#   'de': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'it': 'Bitcoin',
#   'pl': 'Bitcoin',
#   'ro': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'nl': 'Bitcoin',
#   'pt': 'Bitcoin',
#   'sv': 'Bitcoin',
#   'vi': 'Bitcoin',
#   'tr': 'Bitcoin',
#   'ru': 'биткоин',
#   'ja': 'ビットコイン',
#   'zh': '比特币',
#   'zh-tw': '比特幣',
#   'ko': '비트코인',
#   'ar': 'بيتكوين',
#   'th': 'บิตคอยน์',
#   'id': 'Bitcoin'},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'},
#  'market_data': {'current_price': {'aed': 50024.57906376443,
#    'ars': 253468.12429692186,
#    'aud': 17446.3215245937,
#    'bch': 5.76928286478153,
#    'bdt': 1126110.803183989,
#    'bhd': 5132.860612995706,
#    'bmd': 13620.3618741461,
#    'brl': 45117.7211153463,
#    'btc': 1.0,
# ...

# %%
cg.get_coin_history_by_id('bitcoin','01-01-1990, 01-01-2020')
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'localization': {'en': 'Bitcoin',
#   'de': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'it': 'Bitcoin',
#   'pl': 'Bitcoin',
#   'ro': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'nl': 'Bitcoin',
#   'pt': 'Bitcoin',
#   'sv': 'Bitcoin',
#   'vi': 'Bitcoin',
#   'tr': 'Bitcoin',
#   'ru': 'биткоин',
#   'ja': 'ビットコイン',
#   'zh': '比特币',
#   'zh-tw': '比特幣',
#   'ko': '비트코인',
#   'ar': 'بيتكوين',
#   'th': 'บิตคอยน์',
#   'id': 'Bitcoin'},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1547033579',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1547033579'}}

# %%
btc_df = pd.DataFrame(cg.get_coin_market_chart_by_id('bitcoin',vs_currency='usd',days = 6000,))

# %%
btc_df.head()
# Out:
#                     prices                    market_caps  \
# 0   [1367107200000, 135.3]    [1367107200000, 1500517590]
# 1  [1367193600000, 141.96]  [1367193600000, 1575032004.0]
# 2   [1367280000000, 135.3]  [1367280000000, 1501657493.0]
# 3   [1367366400000, 117.0]  [1367366400000, 1298951550.0]
# 4  [1367452800000, 103.43]  [1367452800000, 1148667722.0]
#
#           total_volumes
# 0    [1367107200000, 0]
# 1  [1367193600000, 0.0]
# 2  [1367280000000, 0.0]
# 3  [1367366400000, 0.0]
# 4  [1367452800000, 0.0]

# %%
btc_df.to_csv("test_btc_df.csv", encoding='utf-8', index=False)

# %%
btc_df.head()
# Out:
#                     prices                    market_caps  \
# 0   [1367107200000, 135.3]    [1367107200000, 1500517590]
# 1  [1367193600000, 141.96]  [1367193600000, 1575032004.0]
# 2   [1367280000000, 135.3]  [1367280000000, 1501657493.0]
# 3   [1367366400000, 117.0]  [1367366400000, 1298951550.0]
# 4  [1367452800000, 103.43]  [1367452800000, 1148667722.0]
#
#           total_volumes Time
# 0    [1367107200000, 0]
# 1  [1367193600000, 0.0]
# 2  [1367280000000, 0.0]
# 3  [1367366400000, 0.0]
# 4  [1367452800000, 0.0]

# %%
btc_df_cleaned = pd.DataFrame(btc_df)

# %%
btc_df_cleaned[["prices","times"]] = pd.DataFrame(btc_df_cleaned.prices.tolist(),index= btc_df_cleaned.index)

# %%
btc_df_cleaned.head()
# Out:
#           prices                    market_caps         total_volumes Time  \
# 0  1367107200000    [1367107200000, 1500517590]    [1367107200000, 0]
# 1  1367193600000  [1367193600000, 1575032004.0]  [1367193600000, 0.0]
# 2  1367280000000  [1367280000000, 1501657493.0]  [1367280000000, 0.0]
# 3  1367366400000  [1367366400000, 1298951550.0]  [1367366400000, 0.0]
# 4  1367452800000  [1367452800000, 1148667722.0]  [1367452800000, 0.0]
#
#     times
# 0  135.30
# 1  141.96
# 2  135.30
# 3  117.00
# 4  103.43
